# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('matches - matches.csv')

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head(6) #top rows
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
df.tail(5)
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.shape#property so ()
# Out:
# (636, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=636, step=1)

# %%
x=df.to_numpy

# %%
x
# Out:
# <bound method DataFrame.to_numpy of       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_index(axis=1)
# Out:
#           city        date  dl_applied   id player_of_match  result  season  \
# 0    Hyderabad  2017-04-05           0    1    Yuvraj Singh  normal    2017
# 1         Pune  2017-04-06           0    2       SPD Smith  normal    2017
# 2       Rajkot  2017-04-07           0    3         CA Lynn  normal    2017
# 3       Indore  2017-04-08           0    4      GJ Maxwell  normal    2017
# 4    Bangalore  2017-04-08           0    5       KM Jadhav  normal    2017
# ..         ...         ...         ...  ...             ...     ...     ...
# 631     Raipur  2016-05-22           0  632         V Kohli  normal    2016
# 632  Bangalore  2016-05-24           0  633  AB de Villiers  normal    2016
# 633      Delhi  2016-05-25           0  634    MC Henriques  normal    2016
# 634      Delhi  2016-05-27           0  635       DA Warner  normal    2016
# 635  Bangalore  2016-05-29           0  636     BCJ Cutting  normal    2016
#
# ...

# %%
df["city"]
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
df.iloc[100:102] #fectching rows from table
# Out:
#       id  season       city        date             team1  \
# 100  101    2008     Jaipur  2008-05-17  Rajasthan Royals
# 101  102    2008  Hyderabad  2008-05-18    Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 100  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 101              Deccan Chargers              Deccan Chargers         field
#
#      result  dl_applied            winner  win_by_runs  win_by_wickets  \
# 100  normal           0  Rajasthan Royals           65               0
# 101  normal           0    Mumbai Indians           25               0
#
#     player_of_match                                      venue      umpire1  \
# 100        GC Smith                     Sawai Mansingh Stadium    BF Bowden
# 101        DJ Bravo  Rajiv Gandhi International Stadium, Uppal  BR Doctrove
#
#         umpire2  umpire3
# 100  SL Shastri      NaN
# 101   DJ Harper      NaN

# %%
df.iloc[[1,2,4],[4,5,10]]
# Out:
#                          team1                   team2  \
# 1               Mumbai Indians  Rising Pune Supergiant
# 2                Gujarat Lions   Kolkata Knight Riders
# 4  Royal Challengers Bangalore        Delhi Daredevils
#
#                         winner
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 4  Royal Challengers Bangalore

# %%
df.loc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
df.iat[635,0]
# Out:
# 636

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
x1=df[(df['season']>2016) & (df['team1']=='Rising Pune Supergiant')]

# %%
x1
# Out:
#     id  season       city        date                   team1  \
# 3    4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 12  13    2017     Rajkot  2017-04-14  Rising Pune Supergiant
# 16  17    2017  Bangalore  2017-04-16  Rising Pune Supergiant
# 27  28    2017     Mumbai  2017-04-24  Rising Pune Supergiant
# 28  29    2017       Pune  2017-04-26  Rising Pune Supergiant
# 32  33    2017       Pune  2017-04-29  Rising Pune Supergiant
# 42  43    2017  Hyderabad  2017-05-06  Rising Pune Supergiant
# 55  56    2017     Mumbai  2017-05-16  Rising Pune Supergiant
#
#                           team2                  toss_winner toss_decision  \
# 3               Kings XI Punjab              Kings XI Punjab         field
# 12                Gujarat Lions                Gujarat Lions         field
# 16  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 27               Mumbai Indians               Mumbai Indians         field
# ...

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
x2=df[(df['toss_decision']=='bat') & (df['toss_winner']==df['winner'])] 
x2
# Out:
#       id  season           city        date                        team1  \
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 14    15    2017          Delhi  2017-04-15             Delhi Daredevils
# 20    21    2017      Hyderabad  2017-04-19          Sunrisers Hyderabad
# 50    51    2017          Delhi  2017-05-12             Delhi Daredevils
# 54    55    2017          Delhi  2017-05-14  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 569  570    2015         Mumbai  2015-05-16             Rajasthan Royals
# 572  573    2015         Mumbai  2015-05-19               Mumbai Indians
# 573  574    2015           Pune  2015-05-20  Royal Challengers Bangalore
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
x3=df[(df['toss_decision']=='field') & (df['toss_winner']==df['winner'])] 
x3
# Out:
#       id  season       city        date                   team1  \
# 1      2    2017       Pune  2017-04-06          Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...        ...         ...                     ...
# 627  628    2016     Raipur  2016-05-20     Sunrisers Hyderabad
# 629  630    2016     Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016     Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016      Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
x4=pd.concat([x3,x2])
x4
# Out:
#       id  season           city        date                        team1  \
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# ..   ...     ...            ...         ...                          ...
# 569  570    2015         Mumbai  2015-05-16             Rajasthan Royals
# 572  573    2015         Mumbai  2015-05-19               Mumbai Indians
# 573  574    2015           Pune  2015-05-20  Royal Challengers Bangalore
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
import matplotlib.pyplot as plt
x4['toss_decision'].value_counts().plot(kind='pie')
x4
# Out:
#       id  season           city        date                        team1  \
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# ..   ...     ...            ...         ...                          ...
# 569  570    2015         Mumbai  2015-05-16             Rajasthan Royals
# 572  573    2015         Mumbai  2015-05-19               Mumbai Indians
# 573  574    2015           Pune  2015-05-20  Royal Challengers Bangalore
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
x4.shape
# Out:
# (325, 18)

# %%
df.shape
# Out:
# (636, 18)

# %%
x4[x4['toss_decision']=='field']
# Out:
#       id  season       city        date                   team1  \
# 1      2    2017       Pune  2017-04-06          Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...        ...         ...                     ...
# 627  628    2016     Raipur  2016-05-20     Sunrisers Hyderabad
# 629  630    2016     Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016     Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016      Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
x4
# Out:
#       id  season           city        date                        team1  \
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# ..   ...     ...            ...         ...                          ...
# 569  570    2015         Mumbai  2015-05-16             Rajasthan Royals
# 572  573    2015         Mumbai  2015-05-19               Mumbai Indians
# 573  574    2015           Pune  2015-05-20  Royal Challengers Bangalore
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_index()
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_values(["city","date"],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#df.fillna(value=10)->it fills the nan data with value 5
#df.dropna() ->it drops which has null values

# %%
df.drop_duplicates(subset=['city'],keep="first")
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
df.drop_duplicates('season',keep='last').sort_values(by='season')[['season','winner']]
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...
